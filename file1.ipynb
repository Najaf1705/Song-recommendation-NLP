# %%
import pandas as pd
import numpy as np

# %%
songs=pd.read_csv("songs.csv")

# %%
songs=songs.drop('link',axis=1).reset_index(drop=True)

# %%
songs
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \nAnd...
# 1      Take it easy with me, please  \nTouch me gentl...
# 2      I'll never know why I had to go  \nWhy I had t...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# ...

# %% [markdown]
# Preprocessing

# %%
songs['text']=songs['text'].str.lower().str.replace('\r', '').str.replace('\n', '')

# %%
songs
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      look at her face, it's a wonderful face  and i...
# 1      take it easy with me, please  touch me gently ...
# 2      i'll never know why i had to go  why i had to ...
# 3      making somebody happy is a question of give an...
# 4      making somebody happy is a question of give an...
# ...                                                  ...
# ...

# %%
# songs['text']=songs['text'].str.replace('\\r', '').str.replace('\\n', '')
songs['song']=songs['song'].str.lower()

# %%
songs = songs[songs['artist'].isin(["Travis Scott", "Adele", "Beyoncé", "Ed Sheeran", "Taylor Swift", "Bruno Mars", "Ariana Grande", "The Weeknd", "Lady Gaga", "Rihanna", "Justin Bieber", "Sam Smith", "Billie Eilish", "Post Malone", "Drake", "Katy Perry", "Shawn Mendes", "Sia", "John Legend", "Dua Lipa", "Harry Styles", "Maroon 5", "Kendrick Lamar", "Imagine Dragons", "Coldplay", "P!nk", "Camila Cabello", "Demi Lovato", "Halsey", "Selena Gomez", "Charlie Puth", "Lizzo", "Lorde", "Eminem", "Lana Del Rey", "Alessia Cara", "Doja Cat", "Lewis Capaldi", "Lauv", "Marshmello", "Khalid", "Twenty One Pilots", "Panic! At The Disco", "Mariah Carey", "Cardi B", "Megan Thee Stallion", "Nicki Minaj", "Ellie Goulding", "Calvin Harris", "Zedd", "Miley Cyrus", "Tones and I", "Ava Max", "Zayn", "Troye Sivan", "SZA", "Lil Nas X", "J Balvin", "Bad Bunny", "Maluma", "Shakira", "Jennifer Lopez", "Pitbull", "Jason Derulo", "Daft Punk", "The Chainsmokers", "Zedd", "David Guetta", "Avicii", "Bastille", "Hozier", "James Arthur", "Jess Glynne", "Clean Bandit", "Ellie Goulding", "Rita Ora", "Bebe Rexha", "Jessie J", "Meghan Trainor", "Charlie XCX", "Tove Lo", "Rag'n'Bone Man", "George Ezra", "Anne-Marie", "Jax Jones", "Jonas Blue", "Sigala", "Disclosure", "Sam Feldt", "Kygo", "Martin Garrix", "Alan Walker", "Galantis", "Diplo", "Major Lazer", "DJ Snake", "Skrillex", "Flume", "Rudimental", "Disclosure", "Years & Years", "Jess Glynne", "Ella Henderson", "Becky Hill", "Joel Corry", "MNEK"])]

# %%
# get random 5000 songs
# songs=songs.sample(2000).reset_index(drop=True)
songs=songs.reset_index(drop=True)

# %%
songs['recommend'] = None

# %%
songs
# Out:
#                  artist            song  \
# 0                 Adele       all i ask
# 1                 Adele    can't let go
# 2                 Adele   crazy for you
# 3                 Adele      daydreamer
# 4                 Adele           hello
# ...                 ...             ...
# 2627  Twenty One Pilots  semi-automatic
# 2628  Twenty One Pilots  taken by sleep
# 2629  Twenty One Pilots       the judge
# 2630  Twenty One Pilots        trapdoor
# 2631  Twenty One Pilots           trees
#
#                                                    text recommend
# 0     [verse 1]  i will leave my heart at the door  ...      None
# 1     [verse 1]  when did it go wrong, i will never ...      None
# 2     found myself today singing out your name,  you...      None
# 3     daydreamer  sitting on the sea  soaking up the...      None
# 4     [verse 1]  hello, it's me  i was wondering if ...      None
# ...                                                 ...       ...
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# Download necessary datasets
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Initialize the stemmer
stemmer = PorterStemmer()

# Get the list of stopwords in English
stop_words = set(stopwords.words('english'))

# %%
def token(elm):
    tok = nltk.word_tokenize(elm)
    a = [stemmer.stem(x) for x in tok if x.lower() not in stop_words]
    return ' '.join(a)

# %%
songs['text'] = songs['text'].apply(lambda x: token(x))

# %%
songs
# Out:
#                  artist            song  \
# 0                 Adele       all i ask
# 1                 Adele    can't let go
# 2                 Adele   crazy for you
# 3                 Adele      daydreamer
# 4                 Adele           hello
# ...                 ...             ...
# 2627  Twenty One Pilots  semi-automatic
# 2628  Twenty One Pilots  taken by sleep
# 2629  Twenty One Pilots       the judge
# 2630  Twenty One Pilots        trapdoor
# 2631  Twenty One Pilots           trees
#
#                                                    text recommend
# 0     [ vers 1 ] leav heart door wo n't say word 've...      None
# 1     [ vers 1 ] go wrong , never know love life slo...      None
# 2     found today sing name , said 'm crazi , 'm cra...      None
# 3     daydream sit sea soak sun real lover make past...      None
# 4     [ vers 1 ] hello , 's wonder year 'd like meet...      None
# ...                                                 ...       ...
# ...

# %%
songs['artist']=songs['artist'].str.lower()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid=TfidfVectorizer(analyzer='word')

# %%
matrix=tfid.fit_transform(songs['text'])

# %%
similarity=cosine_similarity(matrix)

# %%
similarity[0]
# Out:
# array([1.        , 0.12508816, 0.03287493, ..., 0.0968893 , 0.14340893,
#        0.02639585])

# %% [markdown]
# Recommender function

# %%
def recommender(song_name):
    try:
        i = songs[songs['song'] == song_name].index[0]
    except IndexError:
        # Handle the case where the song doesn't exist
        return ["Sorry song not found in database"]

    distances = sorted(enumerate(similarity[i]), key=lambda x: x[1], reverse=True)
    song_indices = [index for index, _ in distances[1:11]]  # Exclude the input song itself

    recommended_songs = []
    for index in song_indices:
        song = songs.loc[index, 'song']
        artist = songs.loc[index, 'artist']
        recommended_songs.append(song + '   ' + artist + '\n')

    return ''.join(recommended_songs)

# %%
for index, row in songs.iterrows():
    song_name = row['song']
    recommendations = recommender(song_name)
    songs.at[index, 'recommend'] = recommendations

# %%
songs['recommend'].iloc[84]
# Out:
# "breakout   miley cyrus\nbreakout   katy perry\nhalcyon   ellie goulding\nthis is our song   demi lovato\nbe alright   ariana grande\nso what   p!nk\nyou're gonna love me   lana del rey\ntake it all   adele\nbrand new day   demi lovato\na message   coldplay\n"

# %%
songs
# Out:
#                  artist            song  \
# 0                 adele       all i ask
# 1                 adele    can't let go
# 2                 adele   crazy for you
# 3                 adele      daydreamer
# 4                 adele           hello
# ...                 ...             ...
# 2627  twenty one pilots  semi-automatic
# 2628  twenty one pilots  taken by sleep
# 2629  twenty one pilots       the judge
# 2630  twenty one pilots        trapdoor
# 2631  twenty one pilots           trees
#
#                                                    text  \
# 0     [ vers 1 ] leav heart door wo n't say word 've...
# 1     [ vers 1 ] go wrong , never know love life slo...
# 2     found today sing name , said 'm crazi , 'm cra...
# 3     daydream sit sea soak sun real lover make past...
# 4     [ vers 1 ] hello , 's wonder year 'd like meet...
# ...                                                 ...
# 2627  night fall , graviti . earth turn , saniti tak...
# ...

# %%
# import json

# data_to_export = {
#     "songs": songs.to_dict(orient="records")
# }

# with open('songsmodel.json', 'w') as file:
#     json.dump(data_to_export, file)

# %%
recommendation = recommender('l')
print(recommendation)
# Out:
# ['Sorry song not found in database']

# %%
ss=songs[songs['song'].isin(["shawn mendes", "miley cyrus"])]
ss
# Out:
# Empty DataFrame
# Columns: [artist, song, text, recommend]
# Index: []
